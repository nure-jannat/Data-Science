# %%
import pandas as pd
import seaborn as sns

# %%
data_dic = {'A':[12,15,45,71],

            'B':[18,26,50,80],

            'C':[32,48,78,93],

            'D':[29,35,63,81]}
df = pd.DataFrame(data_dic)
df
# Out:
#     A   B   C   D
# 0  12  18  32  29
# 1  15  26  48  35
# 2  45  50  78  63
# 3  71  80  93  81

# %%
sns.heatmap(df, annot=True, vmin=20, vmax=100)
# Out:
# <Axes: >
