# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('shop data.csv')

# %%
df
# Out:
#       age  income  gender m_status buys
# 0     <25    high    male   single   no
# 1     <25    high    male  married   no
# 2   25-35    high    male   single  yes
# 3     >35  medium    male   single  yes
# 4     >35     low  female   single  yes
# 5     >35     low  female   single   no
# 6   25-35     low  female  married  yes
# 7     <25  medium    male  married   no
# 8     <25     low  female   single  yes
# 9     >35  medium  female  married  yes
# 10    <25  medium  female   single  yes
# 11  25-35  medium    male  married  yes
# 12  25-35    high  female   single  yes
# 13    >35  medium    male  married   no
# 14    <25    high    male   single   no
# 15    <25    high  female  married  yes
# 16    >35  medium    male  married  yes
# 17    <25    high  female   single  yes
# 18  25-35  medium  female  married  yes
# 19  25-35    high    male   single  yes
# 20    >35  medium  female  married   no
# 21    <25     low    male   single  yes

# %%
x = df.drop('buys', axis=1) 
#x = df[['age', 'income', 'gender', 'm_status']]

# %%
x
# Out:
#       age  income  gender m_status
# 0     <25    high    male   single
# 1     <25    high    male  married
# 2   25-35    high    male   single
# 3     >35  medium    male   single
# 4     >35     low  female   single
# 5     >35     low  female   single
# 6   25-35     low  female  married
# 7     <25  medium    male  married
# 8     <25     low  female   single
# 9     >35  medium  female  married
# 10    <25  medium  female   single
# 11  25-35  medium    male  married
# 12  25-35    high  female   single
# 13    >35  medium    male  married
# 14    <25    high    male   single
# 15    <25    high  female  married
# 16    >35  medium    male  married
# 17    <25    high  female   single
# 18  25-35  medium  female  married
# 19  25-35    high    male   single
# 20    >35  medium  female  married
# 21    <25     low    male   single

# %%
#y = df.iloc[:,4]
y = df.buys

# %%
y

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_x = LabelEncoder()
x = x.apply(le_x.fit_transform)

# %%
x
# Out:
#     age  income  gender  m_status
# 0     1       0       1         1
# 1     1       0       1         0
# 2     0       0       1         1
# 3     2       2       1         1
# 4     2       1       0         1
# 5     2       1       0         1
# 6     0       1       0         0
# 7     1       2       1         0
# 8     1       1       0         1
# 9     2       2       0         0
# 10    1       2       0         1
# 11    0       2       1         0
# 12    0       0       0         1
# 13    2       2       1         0
# 14    1       0       1         1
# 15    1       0       0         0
# 16    2       2       1         0
# 17    1       0       0         1
# 18    0       2       0         0
# 19    0       0       1         1
# 20    2       2       0         0
# 21    1       1       1         1

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30, random_state=42)

# %%
xtrain
# Out:
#     age  income  gender  m_status
# 11    0       2       1         0
# 3     2       2       1         1
# 4     2       1       0         1
# 17    1       0       0         1
# 12    0       0       0         1
# 18    0       2       0         0
# 16    2       2       1         0
# 2     0       0       1         1
# 9     2       2       0         0
# 21    1       1       1         1
# 7     1       2       1         0
# 10    1       2       0         1
# 14    1       0       1         1
# 19    0       0       1         1
# 6     0       1       0         0

# %%
xtest
# Out:
#     age  income  gender  m_status
# 0     1       0       1         1
# 13    2       2       1         0
# 8     1       1       0         1
# 1     1       0       1         0
# 15    1       0       0         0
# 5     2       1       0         1
# 20    2       2       0         0

# %%
ytest
# Out:
# 0      no
# 13     no
# 8     yes
# 1      no
# 15    yes
# 5      no
# 20     no
# Name: buys, dtype: object

# %%
ytrain
# Out:
# 11    yes
# 3     yes
# 4     yes
# 17    yes
# 12    yes
# 18    yes
# 16    yes
# 2     yes
# 9     yes
# 21    yes
# 7      no
# 10    yes
# 14     no
# 19    yes
# 6     yes
# Name: buys, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dect = DecisionTreeClassifier()

# %%
dect.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dect.predict(xtest)
# Out:
# array(['no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes'], dtype=object)

# %%
dect.score(xtest, ytest)
# Out:
# 0.5714285714285714

# %% [markdown]
# **Performance using cross_val_score**

# %%
from sklearn.model_selection import cross_val_score

# %%
result = cross_val_score(DecisionTreeClassifier(), x, y, cv=5)
result
# Out:
# array([0.6 , 0.6 , 0.75, 0.25, 0.5 ])

# %%
result.mean()
# Out:
# 0.54

# %%
from sklearn.linear_model import LogisticRegression
result = cross_val_score(LogisticRegression(), x, y, cv=5)
result
# Out:
# array([0.4 , 0.6 , 0.75, 0.5 , 0.75])

# %%
result.mean()
# Out:
# 0.6

# %%
from sklearn.neighbors import KNeighborsClassifier
result = cross_val_score(KNeighborsClassifier(n_neighbors=3), x, y, cv=5)
result
# Out:
# array([0.4 , 0.4 , 0.75, 0.5 , 0.5 ])

# %%
result.mean()
# Out:
# 0.51

# %%
y_predict = dect.predict(xtest)
y_predict
# Out:
# array(['no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes'], dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(ytest,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#           no       1.00      0.40      0.57         5
#          yes       0.40      1.00      0.57         2
#
#     accuracy                           0.57         7
#    macro avg       0.70      0.70      0.57         7
# weighted avg       0.83      0.57      0.57         7

# %%
#xinput = np.array([1,0,0,1])
xinput = np.array([1,0,1,1])

# %%
y_predict = dect.predict([xinput])

# %%
y_predict

# %%
from sklearn import tree
from matplotlib import pyplot as plt
fig=plt.figure(figsize=(30,20))
tree.plot_tree(dect, feature_names=x.columns, filled=True, fontsize=20)
# Out:
# [Text(0.3333333333333333, 0.9166666666666666, 'gender <= 0.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.16666666666666666, 0.75, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5, 0.75, 'age <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'age <= 1.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.5, 0.4166666666666667, 'm_status <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.25, 'income <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %% [markdown]
# ### Tree Explanation

# %% [markdown]
# <img src="tree.jpg" />

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt


data = {
    'Weather': ['Sunny', 'Sunny', 'Sunny', 'Sunny', 'Sunny', 'Rainy', 'Rainy', 'Rainy', 'Rainy', 'Rainy'],
    'Humidity': ['Normal', 'Normal', 'Normal', 'High', 'High', 'High', 'Low', 'Low', 'Low', 'Low'],
    'Wind': ['Weak', 'Weak', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak', 'Strong', 'Weak'],
    'Play': ['No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
}

df = pd.DataFrame(data)


le = LabelEncoder()
df['Weather'] = le.fit_transform(df['Weather'])
df['Humidity'] = le.fit_transform(df['Humidity'])
df['Wind'] = le.fit_transform(df['Wind'])
df['Play'] = le.fit_transform(df['Play'])


X = df.drop('Play', axis=1)
y = df['Play']


clf = DecisionTreeClassifier(criterion='entropy')  # You can use 'gini' or 'entropy' as the criterion


clf.fit(X, y)


plt.figure(figsize=(12, 8))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=['No', 'Yes'], fontsize=10)
plt.show()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create a DataFrame with the provided entropy values
data = {
    'Feature': ['Weather', 'Humidity', 'Wind'],
    'Entropy': [0.124, 0.6, 0.0]
}

df = pd.DataFrame(data)

# Separate features (X) and target (y)
X = df.drop('Entropy', axis=1)
y = df['Entropy']

# Create a Decision Tree Regressor (since we are using entropy values)
regressor = DecisionTreeRegressor(criterion='mse')  # 'mse' is used for regression

# Fit the regressor to the data
regressor.fit(X, y)

# Visualize the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(regressor, filled=True, feature_names=X.columns)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[4], line 23
#      20 regressor = DecisionTreeRegressor(criterion='mse')  # 'mse' is used for regression
#      22 # Fit the regressor to the data
# ---> 23 regressor.fit(X, y)
#      25 # Visualize the Decision Tree
#      26 plt.figure(figsize=(12, 8))
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create a DataFrame with the provided entropy values
data = {
    'Feature': ['Weather', 'Humidity', 'Wind'],
    'Entropy': [0.124, 0.6, 0.0]
}

df = pd.DataFrame(data)
df
# Out:
#     Feature  Entropy
# 0   Weather    0.124
# 1  Humidity    0.600
# 2      Wind    0.000

# %%
# Separate features (X) and target (y)
y = df.drop('Entropy', axis=1)
X = df['Entropy'].reshape(1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Separate features (X) and target (y)
#       2 y = df.drop('Entropy', axis=1)
# ----> 3 X = df['Entropy'].reshape(1,1)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=0)

# Fit the classifier to the data
clf.fit([], )
tree.plot_tree(clf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       2 clf = DecisionTreeClassifier(random_state=0)
#       4 # Fit the classifier to the data
# ----> 5 clf.fit([[0.124, 0.6, 0.0]], ['Weather', 'Humidity', 'Wind'])
#       6 tree.plot_tree(clf)
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# ...

# %%
# Visualize the Decision Tree
plt.figure(figsize=(8, 6))
plot_tree(clf, filled=True, feature_names=X.columns)
plt.show()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create a DataFrame with the provided entropy values
data = {
    'Feature': [1, 2, 3],  # Dummy labels for features
    'Entropy': [0.124, 0.6, 0.0]
}

df = pd.DataFrame(data)

# Separate features (X) and target (y)
X = df.drop('Entropy', axis=1)
y = df['Entropy']

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(criterion='entropy')

# Fit the classifier to the data
clf.fit(X, y)

# Visualize the Decision Tree
plt.figure(figsize=(8, 6))
plot_tree(clf, filled=True, feature_names=X.columns)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 22
#      19 clf = DecisionTreeClassifier(criterion='entropy')
#      21 # Fit the classifier to the data
# ---> 22 clf.fit(X, y)
#      24 # Visualize the Decision Tree
#      25 plt.figure(figsize=(8, 6))
#
# File C:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# ...

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(random_state=0)

# %%
clf = clf.fit([
    [0.124],
    [0.6],
    [0.0]
], ['Weather', 'Humidity', 'Wind'])
tree.plot_tree(clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= 0.062\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6, 0.5, 'x[0] <= 0.362\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]')]

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create a DataFrame with the provided data
data = {
    'Weather': ['Sunny', 'Sunny', 'Sunny', 'Sunny', 'Sunny', 'Rainy', 'Rainy', 'Rainy', 'Rainy', 'Rainy'],
    'Humidity': ['Normal', 'Normal', 'Normal', 'High', 'High', 'High', 'Low', 'Low', 'Low', 'Low'],
    'Wind': ['Weak', 'Weak', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak', 'Strong', 'Weak'],
    'Play': ['No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
}

df = pd.DataFrame(data)

# Encode categorical features to numerical values
le = LabelEncoder()
df['Weather'] = le.fit_transform(df['Weather'])
df['Humidity'] = le.fit_transform(df['Humidity'])
df['Wind'] = le.fit_transform(df['Wind'])
df['Play'] = le.fit_transform(df['Play'])

# Separate features (X) and target (y)
X = df.drop('Play', axis=1)
y = df['Play']

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=0)

# Fit the classifier to the data
clf.fit(X, y)

# Visualize the Decision Tree
plt.figure(figsize=(10, 6))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=['No', 'Yes'])
plt.show()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create a DataFrame with the provided Gain values
data = {
    'Feature': ['Weather', 'Humidity', 'Wind'],
    'Gain': [0.124, 0.6, 0.0]
}

df = pd.DataFrame(data)

# Create a Decision Tree Classifier with a custom splitting criterion
class CustomDecisionTreeClassifier(DecisionTreeClassifier):
    def find_best_split(self, X, y):
        # Modify this method to use the provided Gain values for splitting criteria
        best_feature = None
        best_gain = -1
        
        for feature in X.columns:
            gain = df[df['Feature'] == feature]['Gain'].values[0]  # Get the Gain value for the feature
            if gain > best_gain:
                best_gain = gain
                best_feature = feature
        
        return best_feature, best_gain

clf = CustomDecisionTreeClassifier(criterion='entropy')  # You can use 'entropy' or 'gini' as the criterion
clf.fit(X, y)

# Visualize the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=['No', 'Yes'], fontsize=10)
plt.show()
